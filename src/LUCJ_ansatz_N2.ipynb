# %%
# !pip install ffsim
# Out:
# Collecting ffsim
#   Downloading ffsim-0.0.60-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: jax in /usr/local/lib/python3.12/dist-packages (from ffsim) (0.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ffsim) (2.0.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.12/dist-packages (from ffsim) (3.4.0)
# Requirement already satisfied: orjson in /usr/local/lib/python3.12/dist-packages (from ffsim) (3.11.3)
# Collecting pyscf>=2.9 (from ffsim)
#   Downloading pyscf-2.10.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting qiskit>=1.3 (from ffsim)
#   Downloading qiskit-2.2.1-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from ffsim) (1.16.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ffsim) (4.15.0)
# Requirement already satisfied: h5py>=2.7 in /usr/local/lib/python3.12/dist-packages (from pyscf>=2.9->ffsim) (3.14.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pyscf>=2.9->ffsim) (75.2.0)
# Collecting rustworkx>=0.15.0 (from qiskit>=1.3->ffsim)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.3->ffsim) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit>=1.3->ffsim)
#   Downloading stevedore-5.5.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: jaxlib<=0.5.3,>=0.5.3 in /usr/local/lib/python3.12/dist-packages (from jax->ffsim) (0.5.3)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from jax->ffsim) (0.5.3)
# Downloading ffsim-0.0.60-cp39-abi3-manylinux_2_28_x86_64.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 74.5 MB/s eta 0:00:00
# Downloading pyscf-2.10.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (51.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.2/51.2 MB 50.9 MB/s eta 0:00:00
# Downloading qiskit-2.2.1-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 156.3 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 123.1 MB/s eta 0:00:00
# Downloading stevedore-5.5.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: stevedore, rustworkx, qiskit, pyscf, ffsim
# Successfully installed ffsim-0.0.60 pyscf-2.10.0 qiskit-2.2.1 rustworkx-0.17.1 stevedore-5.5.0

# %%
import pyscf
import pyscf.mcscf
import ffsim
import numpy as np
import scipy.optimize

#mol = pyscf.gto.Mole()

##### Build an H10 molecule with bond length 2 Å
# bond_length = 1.0

# mol.build(
#     atom=[["H", (0, 0, i * bond_length)] for i in range(12)],
#     basis="sto-6g"
# )

bond_length = 1.2

mol = pyscf.gto.Mole()
mol.build(
    atom=[
        ["N", (0, 0, 0)],
        ["N", (0, 0,  bond_length)]
    ],
    basis="sto-6g",
    unit="Angstrom"
)


n_active_electrons = mol.nelectron
n_active_orbitals = mol.nao_nr()

active_space = range(n_active_orbitals)

# Get molecular data and molecular Hamiltonian (one- and two-body tensors)
scf = pyscf.scf.RHF(mol).run()
mol_data = ffsim.MolecularData.from_scf(scf, active_space=active_space)
norb = mol_data.norb
nelec = mol_data.nelec
mol_hamiltonian = mol_data.hamiltonian

# Compute FCI energy
mol_data.run_fci()

print(f"norb = {norb}")
print(f"nelec = {nelec}")
# Out:
# converged SCF energy = -108.535614528761
# Parsing /tmp/tmpvuiim95m
# converged SCF energy = -107.938194421902
# Overwritten attributes  get_ovlp get_hcore  of <class 'pyscf.scf.hf_symm.SymAdaptedRHF'>
# /usr/local/lib/python3.12/dist-packages/pyscf/gto/mole.py:1300: UserWarning: Function mol.dumps drops attribute energy_nuc because it is not JSON-serializable
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/pyscf/gto/mole.py:1300: UserWarning: Function mol.dumps drops attribute intor_symmetric because it is not JSON-serializable
#   warnings.warn(msg)
# CASCI E = -108.727113223000  E(CI) = -130.335182668900  S^2 = 0.0000000
# norb = 10
# nelec = (7, 7)

# %% [markdown]
# CO result, at bond length 1.5 A, -112.354719993162 vs  -112.34728088857229 (full,840 paras) and -112.33880911048277 (local,476)

# %%
import numpy as np
from pyscf import cc

# Get CCSD t2 amplitudes for initializing the ansatz
ccsd = cc.CCSD(
    scf, frozen=[i for i in range(mol.nao_nr()) if i not in active_space]
).run()

# Construct UCJ operator
n_reps = 3
operator = ffsim.UCJOpSpinBalanced.from_t_amplitudes(ccsd.t2, n_reps=n_reps)

# Construct the Hartree-Fock state to use as the reference state
reference_state = ffsim.hartree_fock_state(norb, nelec)

# Apply the operator to the reference state
ansatz_state = ffsim.apply_unitary(reference_state, operator, norb=norb, nelec=nelec)

# Compute the energy ⟨ψ|H|ψ⟩ of the ansatz state
hamiltonian = ffsim.linear_operator(mol_hamiltonian, norb=norb, nelec=nelec)
energy = np.real(np.vdot(ansatz_state, hamiltonian @ ansatz_state))
print(f"Energy at initialization: {energy}")
print('number of paras', len(operator.to_parameters()))
# Out:
# E(CCSD) = -108.7210654096777  E_corr = -0.1854508809166108
# Energy at initialization: -108.68327816921266
# number of paras 630

# %%
import scipy.optimize

def fun(x):
    # Initialize the ansatz operator from the parameter vector
    operator = ffsim.UCJOpSpinBalanced.from_parameters(x, norb=norb, n_reps=n_reps)
    # Apply the ansatz operator to the reference state
    final_state = ffsim.apply_unitary(reference_state, operator, norb=norb, nelec=nelec)
    # Return the energy ⟨ψ|H|ψ⟩ of the ansatz state
    return np.real(np.vdot(final_state, hamiltonian @ final_state))


result = scipy.optimize.minimize(
    fun, x0=operator.to_parameters(), method="L-BFGS-B", options=dict(maxiter=100000, maxfun=5000000, ftol=1e-7)
)

print(f"Number of parameters: {len(result.x)}")
print(result)
# Out:
# Number of parameters: 630
#   message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: -108.70464877225912
#         x: [-3.160e-01  3.167e-01 ...  9.639e-03 -3.909e-02]
#       nit: 28
#       jac: [-2.004e-04 -1.390e-03 ... -3.666e-04 -3.055e-04]
#      nfev: 20192
#      njev: 32
#  hess_inv: <630x630 LbfgsInvHessProduct with dtype=float64>

# %%
pairs_aa = [(p, p + 1) for p in range(norb - 1)]
pairs_ab = [(p, p) for p in range(norb)]
interaction_pairs = (pairs_aa, pairs_ab)


def fun(x):
    operator = ffsim.UCJOpSpinBalanced.from_parameters(
        x, norb=norb, n_reps=n_reps, interaction_pairs=interaction_pairs
    )
    final_state = ffsim.apply_unitary(reference_state, operator, norb=norb, nelec=nelec)
    return np.real(np.vdot(final_state, hamiltonian @ final_state))


result = scipy.optimize.minimize(
    fun,
    x0=operator.to_parameters(interaction_pairs=interaction_pairs),
    method="L-BFGS-B",
    options=dict(maxiter=100000, maxfun=5000000, ftol=1e-7),
)
print(f"Number of parameters: {len(result.x)}")
print(result)
# Out:
# Number of parameters: 357
#   message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: -108.71526456778797
#         x: [-4.503e-01  3.015e-01 ... -2.255e-01 -1.857e-01]
#       nit: 143
#       jac: [ 2.103e-04  3.070e-04 ...  0.000e+00 -1.148e-03]
#      nfev: 53700
#      njev: 150
#  hess_inv: <357x357 LbfgsInvHessProduct with dtype=float64>

# %%
from collections import defaultdict

from ffsim.optimize import minimize_linear_method


# Define function that converts a list of parameters to the corresponding state vector
def params_to_vec(x: np.ndarray) -> np.ndarray:
    operator = ffsim.UCJOpSpinBalanced.from_parameters(
        x, norb=norb, n_reps=n_reps, interaction_pairs=interaction_pairs
    )
    return ffsim.apply_unitary(reference_state, operator, norb=norb, nelec=nelec)


# Define a callback function used to save optimization information (this is optional)
info = defaultdict(list)


def callback(intermediate_result: scipy.optimize.OptimizeResult):
    # The callback function is called after each iteration. It accepts
    # an OptimizeResult object storing the parameters and function value at
    # the current iteration, and possibly other information
    info["x"].append(intermediate_result.x)
    info["fun"].append(intermediate_result.fun)
    if hasattr(intermediate_result, "jac"):
        info["jac"].append(intermediate_result.jac)
    if hasattr(intermediate_result, "regularization"):
        info["regularization"].append(intermediate_result.regularization)
    if hasattr(intermediate_result, "variation"):
        info["variation"].append(intermediate_result.variation)


# Optimize with the linear method
result = minimize_linear_method(
    params_to_vec,
    hamiltonian,
    x0=operator.to_parameters(interaction_pairs=interaction_pairs),
    maxiter=1000,
    callback=callback,
)

# Print some information
print(f"Number of parameters: {len(result.x)}")
print(result)
print()
for i, (fun, jac, regularization, variation) in enumerate(
    zip(info["fun"], info["jac"], info["regularization"], info["variation"])
):
    print(f"Iteration {i + 1}")
    print(f"    Energy: {fun}")
    print(f"    Norm of gradient: {np.linalg.norm(jac)}")
    print(f"    Regularization hyperparameter: {np.linalg.norm(regularization)}")
    print(f"    Variation hyperparameter: {np.linalg.norm(variation)}")
# Out:
# Number of parameters: 357
#  message: Convergence: Relative reduction of objective function <= ftol.
#  success: True
#      fun: -108.71927702442633
#        x: [-1.231e-01  1.996e-01 ... -3.084e-01 -2.942e-01]
#      nit: 92
#      jac: [ 5.547e-04 -1.567e-04 ... -6.399e-07  1.519e-06]
#     nfev: 69604
#     njev: 93
#   nlinop: 36403
#
# Iteration 1
#     Energy: -108.67194400801817
#     Norm of gradient: 0.0941630448968623
#     Regularization hyperparameter: 0.0018318211015259924
#     Variation hyperparameter: 0.9995350890512504
# Iteration 2
#     Energy: -108.68352023577549
#     Norm of gradient: 0.05363166178576294
#     Regularization hyperparameter: 0.0030409191456738107
#     Variation hyperparameter: 0.9995353033152398
# Iteration 3
#     Energy: -108.69011190884964
#     Norm of gradient: 0.04626882820215872
#     Regularization hyperparameter: 0.005193473572002985
#     Variation hyperparameter: 0.9995352349289552
# Iteration 4
#     Energy: -108.69722128813942
#     Norm of gradient: 0.045712980241453025
#     Regularization hyperparameter: 0.0037529434603398447
#     Variation hyperparameter: 0.9995353592342531
# Iteration 5
#     Energy: -108.70310708276054
#     Norm of gradient: 0.03594390592778332
#     Regularization hyperparameter: 0.0026508056501276414
#     Variation hyperparameter: 0.9995354037826099
# Iteration 6
#     Energy: -108.70809609155789
#     Norm of gradient: 0.040972403631873704
#     Regularization hyperparameter: 0.0028106769466647963
#     Variation hyperparameter: 0.999535443731574
# Iteration 7
#     Energy: -108.7107241440994
#     Norm of gradient: 0.028416574520019364
#     Regularization hyperparameter: 0.001311721257727852
#     Variation hyperparameter: 0.99953522534251
# Iteration 8
#     Energy: -108.7121277765832
#     Norm of gradient: 0.025558729127666876
#     Regularization hyperparameter: 0.001528721347325589
#     Variation hyperparameter: 0.9995358274537255
# Iteration 9
#     Energy: -108.71317508780002
#     Norm of gradient: 0.017697082411624012
#     Regularization hyperparameter: 0.0016012951063340713
#     Variation hyperparameter: 0.9995360212303808
# Iteration 10
#     Energy: -108.71387712417446
#     Norm of gradient: 0.025446696191835302
#     Regularization hyperparameter: 0.001642263865619662
#     Variation hyperparameter: 0.999536142353584
# Iteration 11
#     Energy: -108.71449977469956
#     Norm of gradient: 0.01699981290964533
#     Regularization hyperparameter: 0.0005540199184070756
#     Variation hyperparameter: 0.9995381663686643
# Iteration 12
#     Energy: -108.7148858092684
#     Norm of gradient: 0.020507133695496935
#     Regularization hyperparameter: 0.0007916703059701952
#     Variation hyperparameter: 0.9995388969778635
# Iteration 13
#     Energy: -108.71518303940347
#     Norm of gradient: 0.021285334966337107
#     Regularization hyperparameter: 0.0007080149989753345
#     Variation hyperparameter: 0.9995388338722618
# Iteration 14
#     Energy: -108.71540152709056
#     Norm of gradient: 0.02513849823760917
#     Regularization hyperparameter: 0.000551174074873061
#     Variation hyperparameter: 0.9995389202518488
# Iteration 15
#     Energy: -108.71559547952857
#     Norm of gradient: 0.027216558152314496
#     Regularization hyperparameter: 0.0003813588559161297
#     Variation hyperparameter: 0.9995387264840412
# Iteration 16
#     Energy: -108.7157644885828
#     Norm of gradient: 0.027474315166918808
#     Regularization hyperparameter: 0.0005345130979327169
#     Variation hyperparameter: 0.9995391610169253
# Iteration 17
#     Energy: -108.71593994589834
#     Norm of gradient: 0.0301254441424085
#     Regularization hyperparameter: 0.0006417218568788182
#     Variation hyperparameter: 0.9995392997995178
# Iteration 18
#     Energy: -108.71612151936966
#     Norm of gradient: 0.033177855502341536
#     Regularization hyperparameter: 0.0008888760560867853
#     Variation hyperparameter: 0.9995391176745133
# Iteration 19
#     Energy: -108.7163629363463
#     Norm of gradient: 0.037210568170369065
#     Regularization hyperparameter: 0.0005241014271046233
#     Variation hyperparameter: 0.9995390762011234
# Iteration 20
#     Energy: -108.71665181275705
#     Norm of gradient: 0.04438826947565521
#     Regularization hyperparameter: 0.0005712527342387186
#     Variation hyperparameter: 0.9995391511606508
# Iteration 21
#     Energy: -108.7170003889349
#     Norm of gradient: 0.04612885757801581
#     Regularization hyperparameter: 0.0005325876685442207
#     Variation hyperparameter: 0.9995393171344327
# Iteration 22
#     Energy: -108.71735236388274
#     Norm of gradient: 0.04795189035148201
#     Regularization hyperparameter: 0.00047574368640326776
#     Variation hyperparameter: 0.9995394180225632
# Iteration 23
#     Energy: -108.71762719404627
#     Norm of gradient: 0.036734930479471184
#     Regularization hyperparameter: 0.00047360202775046945
#     Variation hyperparameter: 0.9995444751703546
# Iteration 24
#     Energy: -108.71779147440157
#     Norm of gradient: 0.03318922190444953
#     Regularization hyperparameter: 0.00034961769442067606
#     Variation hyperparameter: 0.9995446958858832
# Iteration 25
#     Energy: -108.71788075372005
#     Norm of gradient: 0.029011591138099677
#     Regularization hyperparameter: 0.0002924717261875827
#     Variation hyperparameter: 0.9995450340933245
# Iteration 26
#     Energy: -108.71793973623765
#     Norm of gradient: 0.02887435916729896
#     Regularization hyperparameter: 0.00024146616796530816
#     Variation hyperparameter: 0.9995450083910833
# Iteration 27
#     Energy: -108.71799055096778
#     Norm of gradient: 0.02824818039855938
#     Regularization hyperparameter: 0.00024146617829538016
#     Variation hyperparameter: 0.9995450083872034
# Iteration 28
#     Energy: -108.71803929678208
#     Norm of gradient: 0.029940581791880076
#     Regularization hyperparameter: 0.00027821207835162896
#     Variation hyperparameter: 0.9995447831656074
# Iteration 29
#     Energy: -108.71809056103362
#     Norm of gradient: 0.03431326121740427
#     Regularization hyperparameter: 0.00032899354091999274
#     Variation hyperparameter: 0.9995444719154173
# Iteration 30
#     Energy: -108.71814828147781
#     Norm of gradient: 0.03805780763657036
#     Regularization hyperparameter: 0.00040736205300205634
#     Variation hyperparameter: 0.999544597007435
# Iteration 31
#     Energy: -108.71821547071737
#     Norm of gradient: 0.04308099960096534
#     Regularization hyperparameter: 0.000489656759074671
#     Variation hyperparameter: 0.9995446037903294
# Iteration 32
#     Energy: -108.71829235416716
#     Norm of gradient: 0.048264263732684186
#     Regularization hyperparameter: 0.0005672003621490949
#     Variation hyperparameter: 0.9995445903608505
# Iteration 33
#     Energy: -108.71837481428258
#     Norm of gradient: 0.049603192883129484
#     Regularization hyperparameter: 0.0006471606666384106
#     Variation hyperparameter: 0.9995444278442829
# Iteration 34
#     Energy: -108.71845391543042
#     Norm of gradient: 0.044940735002641403
#     Regularization hyperparameter: 0.0007349073912106135
#     Variation hyperparameter: 0.9995444278442829
# Iteration 35
#     Energy: -108.71852246427342
#     Norm of gradient: 0.04835510169095664
#     Regularization hyperparameter: 0.0006587871190225487
#     Variation hyperparameter: 0.9995441058760022
# Iteration 36
#     Energy: -108.71858433503894
#     Norm of gradient: 0.03857341664251043
#     Regularization hyperparameter: 0.0006582226556480751
#     Variation hyperparameter: 0.999544110381522
# Iteration 37
#     Energy: -108.71863530841075
#     Norm of gradient: 0.04237167146188195
#     Regularization hyperparameter: 0.00047403281294570884
#     Variation hyperparameter: 0.9995440322730473
# Iteration 38
#     Energy: -108.71868574845313
#     Norm of gradient: 0.03901696124456699
#     Regularization hyperparameter: 0.0003449668760885693
#     Variation hyperparameter: 0.9995434954980817
# Iteration 39
#     Energy: -108.71873320100234
#     Norm of gradient: 0.032163286580915655
#     Regularization hyperparameter: 0.0002840439563265336
#     Variation hyperparameter: 0.9995430773667634
# Iteration 40
#     Energy: -108.71877358938228
#     Norm of gradient: 0.025522300415760008
#     Regularization hyperparameter: 0.0002840439621525045
#     Variation hyperparameter: 0.9995430773668283
# Iteration 41
#     Energy: -108.71880583355947
#     Norm of gradient: 0.02341478598799554
#     Regularization hyperparameter: 0.00025280500364284605
#     Variation hyperparameter: 0.9995428796926538
# Iteration 42
#     Energy: -108.71883384791586
#     Norm of gradient: 0.022881695993846568
#     Regularization hyperparameter: 0.00018262667768324982
#     Variation hyperparameter: 0.9995424910535511
# Iteration 43
#     Energy: -108.71886037170087
#     Norm of gradient: 0.025173173190035453
#     Regularization hyperparameter: 0.00012079884853775038
#     Variation hyperparameter: 0.9995429844673303
# Iteration 44
#     Energy: -108.71888559754426
#     Norm of gradient: 0.02733346416174157
#     Regularization hyperparameter: 9.476069582095835e-05
#     Variation hyperparameter: 0.9995433508589688
# Iteration 45
#     Energy: -108.7189099019952
#     Norm of gradient: 0.028592907452190546
#     Regularization hyperparameter: 7.79438304620328e-05
#     Variation hyperparameter: 0.9995435062970982
# Iteration 46
#     Energy: -108.71893296691998
#     Norm of gradient: 0.029854176047491097
#     Regularization hyperparameter: 6.649448315358075e-05
#     Variation hyperparameter: 0.9995435635016627
# Iteration 47
#     Energy: -108.71895412106007
#     Norm of gradient: 0.03204603922399361
#     Regularization hyperparameter: 6.137789636057834e-05
#     Variation hyperparameter: 0.9995434952378923
# Iteration 48
#     Energy: -108.71897325636304
#     Norm of gradient: 0.03192726748865461
#     Regularization hyperparameter: 6.451457674428284e-05
#     Variation hyperparameter: 0.9995435151908887
# Iteration 49
#     Energy: -108.71899011447175
#     Norm of gradient: 0.027100536934926447
#     Regularization hyperparameter: 7.849192769709128e-05
#     Variation hyperparameter: 0.9995433547693316
# Iteration 50
#     Energy: -108.71900430483886
#     Norm of gradient: 0.030270560210498235
#     Regularization hyperparameter: 7.849192764726441e-05
#     Variation hyperparameter: 0.9995433547693309
# Iteration 51
#     Energy: -108.71901772955549
#     Norm of gradient: 0.02697824151223761
#     Regularization hyperparameter: 8.993479259881164e-05
#     Variation hyperparameter: 0.9995429252698529
# Iteration 52
#     Energy: -108.71902903022101
#     Norm of gradient: 0.025594248787685802
#     Regularization hyperparameter: 9.816423312685296e-05
#     Variation hyperparameter: 0.9995436964843651
# Iteration 53
#     Energy: -108.71903891532081
#     Norm of gradient: 0.025004370851659456
#     Regularization hyperparameter: 9.910151366341581e-05
#     Variation hyperparameter: 0.9995437755096699
# Iteration 54
#     Energy: -108.71904762123216
#     Norm of gradient: 0.023183434276134337
#     Regularization hyperparameter: 0.00010217623994344252
#     Variation hyperparameter: 0.9995438965549962
# Iteration 55
#     Energy: -108.71905509427378
#     Norm of gradient: 0.020684095956064668
#     Regularization hyperparameter: 0.00010706554714146222
#     Variation hyperparameter: 0.9995441451347236
# Iteration 56
#     Energy: -108.71906140340408
#     Norm of gradient: 0.01936099087610887
#     Regularization hyperparameter: 0.00010706585904516143
#     Variation hyperparameter: 0.9995441438230435
# Iteration 57
#     Energy: -108.71906689652216
#     Norm of gradient: 0.01799131480911264
#     Regularization hyperparameter: 0.00010706585879080684
#     Variation hyperparameter: 0.9995441438229904
# Iteration 58
#     Energy: -108.71907170267741
#     Norm of gradient: 0.016098456232038743
#     Regularization hyperparameter: 0.00011243168768849015
#     Variation hyperparameter: 0.99954392734697
# Iteration 59
#     Energy: -108.71907589061507
#     Norm of gradient: 0.015317383930173305
#     Regularization hyperparameter: 0.00011407957938387531
#     Variation hyperparameter: 0.9995439496847411
# Iteration 60
#     Energy: -108.71907971068828
#     Norm of gradient: 0.014520162543973867
#     Regularization hyperparameter: 0.0001177474385180036
#     Variation hyperparameter: 0.9995439867436693
# Iteration 61
#     Energy: -108.71908324427753
#     Norm of gradient: 0.014636546696339462
#     Regularization hyperparameter: 0.00011774743711740699
#     Variation hyperparameter: 0.9995439867434441
# Iteration 62
#     Energy: -108.71908665766796
#     Norm of gradient: 0.015007111560394224
#     Regularization hyperparameter: 0.00011774743043099104
#     Variation hyperparameter: 0.9995439867427711
# Iteration 63
#     Energy: -108.71909004203759
#     Norm of gradient: 0.014017824346528311
#     Regularization hyperparameter: 0.00013137852002186463
#     Variation hyperparameter: 0.9995444691352886
# Iteration 64
#     Energy: -108.7190932958242
#     Norm of gradient: 0.013158406774266133
#     Regularization hyperparameter: 0.0001498556666229153
#     Variation hyperparameter: 0.9995439570909281
# Iteration 65
#     Energy: -108.71909647955366
#     Norm of gradient: 0.013765842452286594
#     Regularization hyperparameter: 0.00015797509461529594
#     Variation hyperparameter: 0.9995442100539838
# Iteration 66
#     Energy: -108.71909975741218
#     Norm of gradient: 0.015468062678265036
#     Regularization hyperparameter: 0.00015797464798837844
#     Variation hyperparameter: 0.9995442100623393
# Iteration 67
#     Energy: -108.71910327051121
#     Norm of gradient: 0.013647632898267266
#     Regularization hyperparameter: 0.0001891553258534312
#     Variation hyperparameter: 0.9995449363895685
# Iteration 68
#     Energy: -108.71910671546148
#     Norm of gradient: 0.015664027517625672
#     Regularization hyperparameter: 0.00019054588951354206
#     Variation hyperparameter: 0.9995449534779725
# Iteration 69
#     Energy: -108.71911047178575
#     Norm of gradient: 0.015382597635058455
#     Regularization hyperparameter: 0.00020887841678632926
#     Variation hyperparameter: 0.9995418939220593
# Iteration 70
#     Energy: -108.71911434605332
#     Norm of gradient: 0.016819329472706823
#     Regularization hyperparameter: 0.0002143997024128387
#     Variation hyperparameter: 0.9995423026515207
# Iteration 71
#     Energy: -108.71911854070935
#     Norm of gradient: 0.01770713097337315
#     Regularization hyperparameter: 0.00022123652436743818
#     Variation hyperparameter: 0.9995418785876818
# Iteration 72
#     Energy: -108.71912303488567
#     Norm of gradient: 0.01937058655637153
#     Regularization hyperparameter: 0.00022123651201041435
#     Variation hyperparameter: 0.9995418785875267
# Iteration 73
#     Energy: -108.71912799458946
#     Norm of gradient: 0.01807891018242216
#     Regularization hyperparameter: 0.00024123252498984104
#     Variation hyperparameter: 0.9995421473847794
# Iteration 74
#     Energy: -108.71913316730651
#     Norm of gradient: 0.019379062982228117
#     Regularization hyperparameter: 0.00024123268791688995
#     Variation hyperparameter: 0.9995421473738979
# Iteration 75
#     Energy: -108.71913896253251
#     Norm of gradient: 0.020196778148748543
#     Regularization hyperparameter: 0.0002412335238297833
#     Variation hyperparameter: 0.9995421479130271
# Iteration 76
#     Energy: -108.71914549684612
#     Norm of gradient: 0.02126420861074651
#     Regularization hyperparameter: 0.0002411360039178208
#     Variation hyperparameter: 0.999542140399381
# Iteration 77
#     Energy: -108.7191530287083
#     Norm of gradient: 0.023383063586957815
#     Regularization hyperparameter: 0.00023495625471158855
#     Variation hyperparameter: 0.9995421720606836
# Iteration 78
#     Energy: -108.71916193766688
#     Norm of gradient: 0.027477314561521055
#     Regularization hyperparameter: 0.00021916365284847805
#     Variation hyperparameter: 0.999542212032356
# Iteration 79
#     Energy: -108.71917276663045
#     Norm of gradient: 0.029531861055156126
#     Regularization hyperparameter: 0.00021916078654893786
#     Variation hyperparameter: 0.9995422120278512
# Iteration 80
#     Energy: -108.71918529938858
#     Norm of gradient: 0.03248612675001152
#     Regularization hyperparameter: 0.0002191607252381557
#     Variation hyperparameter: 0.9995422120285619
# Iteration 81
#     Energy: -108.71919952819279
#     Norm of gradient: 0.033453447705548596
#     Regularization hyperparameter: 0.00022827919685041925
#     Variation hyperparameter: 0.9995420376390194
# Iteration 82
#     Energy: -108.71921446099614
#     Norm of gradient: 0.03510701048065735
#     Regularization hyperparameter: 0.0002282791844682451
#     Variation hyperparameter: 0.9995420376390762
# Iteration 83
#     Energy: -108.71922929041382
#     Norm of gradient: 0.0324101510710353
#     Regularization hyperparameter: 0.00023830178813975705
#     Variation hyperparameter: 0.9995422616602727
# Iteration 84
#     Energy: -108.71924215322083
#     Norm of gradient: 0.028987615550284552
#     Regularization hyperparameter: 0.00023830153044968446
#     Variation hyperparameter: 0.9995422616644587
# Iteration 85
#     Energy: -108.71925239500882
#     Norm of gradient: 0.023027719523417742
#     Regularization hyperparameter: 0.00023829174139643685
#     Variation hyperparameter: 0.999542259946856
# Iteration 86
#     Energy: -108.7192597289957
#     Norm of gradient: 0.0168828039197937
#     Regularization hyperparameter: 0.0002382921291765021
#     Variation hyperparameter: 0.9995422599548724
# Iteration 87
#     Energy: -108.71926479689542
#     Norm of gradient: 0.027216971897784614
#     Regularization hyperparameter: 9.258422627579425e-05
#     Variation hyperparameter: 0.9995451705918149
# Iteration 88
#     Energy: -108.71926986046655
#     Norm of gradient: 0.010468792523223892
#     Regularization hyperparameter: 9.190393881952388e-05
#     Variation hyperparameter: 0.9995451131046724
# Iteration 89
#     Energy: -108.71927259393813
#     Norm of gradient: 0.013946145499760101
#     Regularization hyperparameter: 4.435130567617468e-05
#     Variation hyperparameter: 0.9995366734173752
# Iteration 90
#     Energy: -108.71927473945468
#     Norm of gradient: 0.006882671699642129
#     Regularization hyperparameter: 4.4340850318613704e-05
#     Variation hyperparameter: 0.9995366734628193
# Iteration 91
#     Energy: -108.71927601077533
#     Norm of gradient: 0.006208997155731624
#     Regularization hyperparameter: 4.4340850318613704e-05
#     Variation hyperparameter: 0.9995366734628193
# Iteration 92
#     Energy: -108.71927702442633
#     Norm of gradient: 0.009992615777747182
#     Regularization hyperparameter: 3.006415237558748e-05
#     Variation hyperparameter: 0.9995392076657654
